# %%
# !pip install pandas numpy scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in d:\keto\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in d:\keto\anaconda\lib\site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in d:\keto\anaconda\lib\site-packages (1.7.2)
# Requirement already satisfied: matplotlib in d:\keto\anaconda\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in d:\keto\anaconda\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\keto\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\keto\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\keto\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in d:\keto\anaconda\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\keto\anaconda\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\keto\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\keto\anaconda\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\keto\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\keto\anaconda\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\keto\anaconda\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\keto\anaconda\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in d:\keto\anaconda\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\keto\anaconda\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in d:\keto\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "funding": [100000, 500000, 200000, 800000, 300000],
    "team_size": [2, 5, 3, 8, 4],
    "market_size": ["Small", "Large", "Medium", "Large", "Medium"],
    "competition": ["High", "Medium", "High", "Low", "Medium"],
    "experience": ["No", "Yes", "No", "Yes", "Yes"],
    "success": [0, 1, 0, 1, 1]
}

df = pd.DataFrame(data)
df
# Out:
#    funding  team_size market_size competition experience  success
# 0   100000          2       Small        High         No        0
# 1   500000          5       Large      Medium        Yes        1
# 2   200000          3      Medium        High         No        0
# 3   800000          8       Large         Low        Yes        1
# 4   300000          4      Medium      Medium        Yes        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   funding      5 non-null      int64
#  1   team_size    5 non-null      int64
#  2   market_size  5 non-null      object
#  3   competition  5 non-null      object
#  4   experience   5 non-null      object
#  5   success      5 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#             funding  team_size   success
# count       5.00000   5.000000  5.000000
# mean   380000.00000   4.400000  0.600000
# std    277488.73851   2.302173  0.547723
# min    100000.00000   2.000000  0.000000
# 25%    200000.00000   3.000000  0.000000
# 50%    300000.00000   4.000000  1.000000
# 75%    500000.00000   5.000000  1.000000
# max    800000.00000   8.000000  1.000000

# %%
df.isnull().sum()
# Out:
# funding        0
# team_size      0
# market_size    0
# competition    0
# experience     0
# success        0
# dtype: int64

# %%
df.to_csv("cleaned_data.csv", index=False)
